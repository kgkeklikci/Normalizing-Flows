# %%
import warnings 
warnings.filterwarnings('ignore', category=DeprecationWarning)
import numpy as np
import pandas as pd
import scipy # could be irrelevant, possibly needed for scatter_matrix 
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
# %matplotlib inline
plt.style.use('seaborn')

import tensorflow as tf
tf.compat.v1.disable_eager_execution() 
import tensorflow_probability as tfp
print(tf.__version__) 

import os 
os.environ['TF_CPP_MIN_LOG_LEVEL']='3'
# Out:
# 2.5.0

# %%
tfd = tfp.distributions
tfb = tfp.bijectors

# %%
session = tf.compat.v1.Session()
# if there exists a session, run session.close() first
tf.compat.v1.set_random_seed(42)

# %%
batch_size=32
DTYPE=tf.float32
NP_DTYPE=np.float32

# %%
# print(os.getcwd())
data_dir = '/Users/kaanguney.keklikci/Desktop/Erasmus+/Heidelberg/data/'
data = pd.read_excel(data_dir+'prostate.xls', engine='xlrd')
data.head()
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
#    patno  stage               rx  dtime                  status   age     wt  \
# 0      1      3  0.2 mg estrogen     72                   alive  75.0   76.0
# 1      2      3  0.2 mg estrogen      1         dead - other ca  54.0  116.0
# 2      3      3  5.0 mg estrogen     40  dead - cerebrovascular  69.0  102.0
# 3      4      3  0.2 mg estrogen     20  dead - cerebrovascular  75.0   94.0
# 4      5      3          placebo     65                   alive  67.0   99.0
#
#                      pf  hx  sbp  dbp                            ekg  \
# 0       normal activity   0   15    9                   heart strain
# 1       normal activity   0   13    7  heart block or conduction def
# 2       normal activity   1   14    8                   heart strain
# 3  in bed < 50% daytime   1   14    7                         benign
# 4       normal activity   0   17   10                         normal
#
#           hg    sz   sg        ap  bm  sdate
# 0  13.798828   2.0  8.0  0.299988   0   2778
# 1  14.599609  42.0  NaN  0.699951   0   2820
# 2  13.398438   3.0  9.0  0.299988   0   2933
# 3  17.597656   4.0  8.0  0.899902   0   2999
# 4  13.398438  34.0  8.0  0.500000   0   3002

# %%
data.isnull().sum()
# Out:
# patno      0
# stage      0
# rx         0
# dtime      0
# status     0
# age        1
# wt         2
# pf         0
# hx         0
# sbp        0
# dbp        0
# ekg        8
# hg         0
# sz         5
# sg        11
# ap         0
# bm         0
# sdate      0
# dtype: int64

# %%
# impute missing values
data = data.dropna(subset = ['ekg', 'age'])
data['sz'] = data['sz'].fillna(value = np.mean(data['sz']))
data['sg'] = data['sg'].fillna(value = np.mean(data["sg"]))
data['wt'] = data['wt'].fillna(value = np.mean(data['wt']))

# check if all are imputed 
assert(data.isnull().all().sum() == 0)

# %%
data.shape, data.describe()
# Out:
# ((493, 18),
#              patno       stage       dtime         age          wt          hx  \
#  count  493.000000  493.000000  493.000000  493.000000  493.000000  493.000000
#  mean   251.176471    3.423935   36.121704   71.444219   99.132383    0.432049
#  std    145.927533    0.494682   23.311024    7.035583   13.361332    0.495864
#  min      1.000000    3.000000    0.000000   48.000000   69.000000    0.000000
#  25%    125.000000    3.000000   14.000000   70.000000   90.000000    0.000000
#  50%    249.000000    3.000000   34.000000   73.000000   98.000000    0.000000
#  75%    377.000000    4.000000   57.000000   76.000000  107.000000    1.000000
#  max    506.000000    4.000000   76.000000   89.000000  152.000000    1.000000
#
#                sbp         dbp          hg          sz          sg          ap  \
#  count  493.000000  493.000000  493.000000  493.000000  493.000000  493.000000
#  mean    14.363083    8.156187   13.445493   14.481557   10.307054   12.210995
#  std      2.409335    1.475390    1.959604   12.205876    2.001298   62.703835
#  min      8.000000    4.000000    5.899414    0.000000    5.000000    0.099991
#  25%     13.000000    7.000000   12.298828    5.000000    9.000000    0.500000
#  50%     14.000000    8.000000   13.699219   11.000000   10.000000    0.699951
#  75%     16.000000    9.000000   14.699219   21.000000   11.000000    2.799805
#  max     30.000000   18.000000   21.199219   69.000000   15.000000  999.875000
#
#                 bm        sdate
#  count  493.000000   493.000000
#  mean     0.160243  3040.269777
#  std      0.367204   222.590409
#  min      0.000000  2652.000000
#  25%      0.000000  2861.000000
#  50%      0.000000  3022.000000
#  75%      0.000000  3205.000000
#  max      1.000000  3465.000000  )

# %%
data.drop(['patno', 'sdate'], axis=1, inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
print(data.rx.unique())
print(data.ekg.unique())
print(data.pf.unique())
data = pd.get_dummies(data)
# Out:
# ['0.2 mg estrogen' '5.0 mg estrogen' 'placebo' '1.0 mg estrogen']
# ['heart strain' 'heart block or conduction def' 'benign' 'normal' 'old MI'
#  'rhythmic disturb & electrolyte ch' 'recent MI']
# ['normal activity' 'in bed < 50% daytime' 'in bed > 50% daytime'
#  'confined to bed']

# %%
columns = data.columns 
data = StandardScaler().fit_transform(data) # returns values, not dataframe
data = pd.DataFrame(data,columns=columns) 
data.head()
# Out:
#       stage     dtime       age        wt        hx       sbp       dbp  \
# 0 -0.857855  1.540676  0.505913 -1.733052 -0.872189  0.264622  0.572507
# 1 -0.857855 -1.508187 -2.481946  1.263703 -0.872189 -0.566325 -0.784444
# 2 -0.857855  0.166541 -0.347761  0.214839  1.146540 -0.150852 -0.105969
# 3 -0.857855 -0.692294  0.505913 -0.384512  1.146540 -0.150852 -0.784444
# 4 -0.857855  1.240084 -0.632319 -0.009918 -0.872189  1.095570  1.250982
#
#          hg        sz        sg  ...  pf_in bed < 50% daytime  \
# 0  0.180493 -1.023625 -1.153950  ...                -0.280668
# 1  0.589552  2.256814  0.000000  ...                -0.280668
# 2 -0.024037 -0.941614 -0.653766  ...                -0.280668
# 3  2.121031 -0.859603 -1.153950  ...                 3.562926
# 4 -0.024037  1.600726 -1.153950  ...                -0.280668
#
#    pf_in bed > 50% daytime  pf_normal activity  ekg_benign  \
# 0                 -0.16457            0.339683   -0.221215
# 1                 -0.16457            0.339683   -0.221215
# 2                 -0.16457            0.339683   -0.221215
# 3                 -0.16457           -2.943920    4.520485
# 4                 -0.16457            0.339683   -0.221215
#
#    ekg_heart block or conduction def  ekg_heart strain  ekg_normal  \
# 0                          -0.235954          1.519449   -0.718974
# 1                           4.238106         -0.658133   -0.718974
# 2                          -0.235954          1.519449   -0.718974
# 3                          -0.235954         -0.658133   -0.718974
# 4                          -0.235954         -0.658133    1.390872
#
#    ekg_old MI  ekg_recent MI  ekg_rhythmic disturb & electrolyte ch
# 0   -0.423587      -0.045083                              -0.339683
# 1   -0.423587      -0.045083                              -0.339683
# 2   -0.423587      -0.045083                              -0.339683
# 3   -0.423587      -0.045083                              -0.339683
# 4   -0.423587      -0.045083                              -0.339683
#
# [5 rows x 37 columns]

# %%
# visualize the figure as line plot for each row 
# remove legend, too long
data.T.plot(figsize=(10,5))
plt.xticks(rotation=45)
plt.legend().remove()
plt.ylabel('Value')
plt.show()

# %%
# alternative visualization: plot densities of hg, sz, wt
scatter_matrix(data[['hg','sz','wt']], figsize=(10,5),diagonal='kde',alpha=0.3)
plt.show()

# %%
""" dataset tensor definition """
dataset = tf.data.Dataset.from_tensor_slices(data.astype(NP_DTYPE))
dataset = dataset.repeat()
dataset = dataset.shuffle(buffer_size=data.shape[0])
dataset = dataset.prefetch(2*batch_size)
dataset = dataset.batch(batch_size)
data_iterator = tf.compat.v1.data.make_one_shot_iterator(dataset)
x_samples = data_iterator.get_next()

# %%
""" forward transformation """
def forward(x):
    y = zeros_like(x)
    event_size = x.shape[-event_dims:].num_elements()
    for _ in range(event_size):
        bijector = bijector_fn(y)
        y = bijector.forward(x)
    return y

""" inverse transformation """
def inverse(y):
    bijector = bijector_fn(y)
    return bijector.inverse(y)

dims = data.shape[1]
print('Dimension count: ' + str(dims))
# Out:
# Dimension count: 37

# %%
shift_scale_function = tfb.AutoregressiveNetwork(params=2, hidden_units=[512, 512])

maf = tfd.TransformedDistribution(
    distribution=tfd.Sample(tfd.Normal(loc=0., scale=1.), sample_shape=[dims]),
    bijector=tfb.MaskedAutoregressiveFlow(shift_and_log_scale_fn=shift_scale_function))

# %%
session.run(tf.compat.v1.global_variables_initializer())

# %%
""" define adam as optimizer, minimize negative log likelihood """
# loss may become negative, note that it's just a scalar 
loss = -tf.reduce_mean(maf.log_prob(x_samples))
train_op = tf.compat.v1.train.AdamOptimizer(1e-4).minimize(loss)

# %%
session.run(tf.compat.v1.global_variables_initializer())

# %%
""" optimize for all dimensions """
NUM_STEPS = int(1e5)
global_step = []
np_losses = []
for i in range(NUM_STEPS):
    _, np_loss = session.run([train_op, loss])
    if i % 100 == 0:
        global_step.append(i)
        np_losses.append(np_loss)
    if i % int(1e4) == 0:
        print('Iteration {iteration}: {loss}'.format(iteration=i,loss=np_loss))
        
""" plot loss """
fig = plt.figure(figsize=(10,5))
x = np.arange(1000)
y = np_losses
m, b = np.polyfit(x, y, 1) 
plt.scatter(x, y, s=10, alpha=0.3)
plt.plot(x, m*x+b, c="r")
plt.title('Loss per 100 iteration')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.tight_layout()
plt.show()
# Out:
# Iteration 0: 58.840599060058594
# Iteration 10000: -17.032711029052734
# Iteration 20000: -26.12310028076172
# Iteration 30000: -35.4915771484375
# Iteration 40000: -31.868289947509766
# Iteration 50000: -36.909576416015625
# Iteration 60000: -33.01026153564453
# Iteration 70000: -36.207550048828125
# Iteration 80000: -39.636131286621094
# Iteration 90000: -40.6751594543457
